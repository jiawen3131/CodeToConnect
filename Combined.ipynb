# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## **Import Libraries**

# %%
import pandas as pd
import heapq
from datetime import datetime

example_clients_df = pd.read_csv("/content/drive/MyDrive/BoA 2024/Data/example/input_clients.csv")
example_instruments_df = pd.read_csv("/content/drive/MyDrive/BoA 2024/Data/example/input_instruments.csv")
example_orders_df = pd.read_csv("/content/drive/MyDrive/BoA 2024/Data/example/input_orders.csv")

test_clients_df = pd.read_csv("/content/drive/MyDrive/BoA 2024/Data/test/input_clients.csv")
test_instruments_df = pd.read_csv("/content/drive/MyDrive/BoA 2024/Data/test/input_instruments.csv")
test_orders_df = pd.read_csv("/content/drive/MyDrive/BoA 2024/Data/test/input_orders.csv")

# %% [markdown]
# ## **Output Dataframes**

# %%
exchange_report_data = {'Order Id': [], 'Rejection Reason': []}
exchange_report_df = pd.DataFrame(exchange_report_data)
exchange_report_df
# Out:
# Empty DataFrame
# Columns: [Order Id, Rejection Reason]
# Index: []

# %% [markdown]
# ## **Preprocessing Dataset**

# %% [markdown]
# ### Open Auction

# %%
test_orders_converted = test_orders_df.copy()
test_orders_converted['Time'] = pd.to_datetime(test_orders_converted['Time'], format='%H:%M:%S', errors='coerce')
test_orders_converted = test_orders_converted[test_orders_converted['Time'].dt.time < pd.to_datetime('09:30:00').time()]
test_orders_converted
# Out:
#                    Time      OrderID Instrument  Quantity      Client   Price  \
# 0   1900-01-01 09:00:00     ORDER_10   INST_000   17500.0  CLIENT_107  Market
# 1   1900-01-01 09:00:00   ORDER_1430   INST_000    3000.0  CLIENT_111  Market
# 2   1900-01-01 09:00:00   ORDER_1860   INST_000   46000.0  CLIENT_113  Market
# 3   1900-01-01 09:00:00     ORDER_20   INST_001    4350.0  CLIENT_106  Market
# 4   1900-01-01 09:00:00   ORDER_2430   INST_001    8700.0  CLIENT_103  Market
# ..                  ...          ...        ...       ...         ...     ...
# 895 1900-01-01 09:29:00   ORDER_9459   INST_008   52000.0  CLIENT_108   100.1
# 896 1900-01-01 09:29:00   ORDER_9889   INST_008   84000.0  CLIENT_111   100.7
# 897 1900-01-01 09:29:00   ORDER_1029   INST_009   15000.0  CLIENT_112   101.0
# 898 1900-01-01 09:29:00  ORDER_10459   INST_009   79000.0  CLIENT_108    99.7
# 899 1900-01-01 09:29:00  ORDER_10889   INST_009   28000.0  CLIENT_111   100.1
#
#      Side
# 0    Sell
# 1    Sell
# 2    Sell
# 3    Sell
# 4     Buy
# ..    ...
# 895   Buy
# 896   Buy
# 897  Sell
# 898  Sell
# 899   Buy
#
# [900 rows x 7 columns]

# %% [markdown]
# ### Check Instrument

# %%
instrument_condition = test_orders_df['Instrument'].isin(test_instruments_df['InstrumentID'])
frames = [test_orders_df, instrument_condition]
result = pd.concat(frames,axis=1, join='inner')
cols=pd.Series(result.columns)

for dup in cols[cols.duplicated()].unique():
    cols[cols[cols == dup].index.values.tolist()] = [dup + '.' + str(i) if i != 0 else dup for i in range(sum(cols == dup))]

# rename the columns with the cols list.
result.columns=cols
filtered_result = result[result['Instrument.1']==False]
filtered_result
# Out:
# Empty DataFrame
# Columns: [Time, OrderID, Instrument, Quantity, Client, Price, Side, Instrument.1]
# Index: []

# %% [markdown]
# ## **Classes**

# %%
class Instrument:
    def __init__(self, instrumentID, currency, lotsize):
      self.instrumentID = instrumentID
      self.currency = currency
      self.lotsize = lotsize
      self.openprice = 0
      self.closeprice = 0
      self.totaltradedvolume = 0
      self.dayhigh = 0
      self.daylow = 0
      self.volumeweightedaverageprice = 0
      self.timeobject = None

# %%
class Order:
  def __init__(self, order_id, timestamp, instrument, price, quantity, client,side):
      self.order_id = order_id
      self.timestamp = timestamp
      self.instrument = instrument
      self.price = price
      self.quantity = quantity
      self.client = client
      self.side = side  # 'buy' or 'sell'

  def __lt__(self, other):
      # Define comparison for order objects (to be used in priority queue)
      # Market orders are considered to have infinite priority
      if self.price == 'Market':
          return True
      elif other.price == 'Market':
          return False
      else:
          return self.price < other.price

# %%
class Client:
    def __init__(self, clientID, currencies, position_check, rating):
      self.clientID = clientID
      self.currencies = currencies
      self.position_check = position_check
      self.rating = rating

# %%
class OpenAuction:
    def __init__(self, positions):
        self.orders_heap = []
        self.positions = positions
        self.match_price = 0


    def add_order(self, orders):
        for order in orders:
            heapq.heappush(self.orders_heap, order)

    def match_orders(self, positions):
        market_orders = []
        limit_orders = []
        match_prices = []
        match_orders = []

        # Separate market and limit orders
        while self.orders_heap:
            order = heapq.heappop(self.orders_heap)
            if order.price == 'Market':
                market_orders.append(order)
            else:
                limit_orders.append(order)

        # Match market orders with limit orders
        for market_order in market_orders:
            while limit_orders:
                limit_order = heapq.heappop(limit_orders)
                if market_order.side != limit_order.side:
                    matched_quantity = min(market_order.quantity, limit_order.quantity)

                    if market_order.side == 'Buy':
                      positions[market_order.client][market_order.instrument] +=  matched_quantity
                      positions[limit_order.client][limit_order.instrument] -=  matched_quantity

                    if market_order.side == 'Sell':
                      positions[limit_order.client][limit_order.instrument] +=  matched_quantity
                      positions[limit_order.client][limit_order.instrument] -=  matched_quantity

                    print(f"Matched order: {market_order.order_id} ({market_order.instrument}) and {limit_order.order_id} ({limit_order.instrument}) for {matched_quantity} at price {limit_order.price}")
                    match_prices.append(limit_order.price)
                    match_orders.append(market_order.order_id)
                    match_orders.append(limit_order.order_id)

                    market_order.quantity -= matched_quantity
                    limit_order.quantity -= matched_quantity
                    if limit_order.quantity > 0:
                        heapq.heappush(limit_orders, limit_order)
                    if market_order.quantity == 0:
                        break

            if market_order.quantity > 0:
                print(f"Unmatched market order: {market_order.order_id} ({market_order.instrument}) for {market_order.quantity} at market price")

        self.match_price = sorted(match_prices,reverse=True)[0]
        return (self.match_price,positions)

# %% [markdown]
# ## **Open Auction Functions**

# %%
def create_order_objects(data):

    orders_list = []

    for index, row in data.iterrows():
        timestamp = row['Time']
        order_id = row['OrderID']
        instrument = row['Instrument']
        quantity = row['Quantity']
        client = row['Client']
        price = row['Price']
        side = row['Side']

        order = Order(order_id,timestamp, instrument, price,quantity, client,side)

        orders_list.append(order)


    return orders_list

# %%
orders = create_order_objects(test_orders_converted)

# %%
def create_instrument_objects(data):

    instruments_list = []

    for index, row in data.iterrows():

        instrumentID = row['InstrumentID']
        currency = row['Currency']
        lotsize = row['LotSize']

        instrument = Instrument(instrumentID, currency, lotsize)

        instruments_list.append(instrument)


    return set(instruments_list)

# %%
instruments_list = create_instrument_objects(test_instruments_df)

# %%
def create_positions(orders, test_instruments_list):
  client_position = {}
  for client in orders:
    client_position[client.client] = {}
    for instrument in test_instruments_list:
      client_position[client.client][instrument.instrumentID] = 0
  return client_position

# %%
positions = create_positions(orders, instruments_list)
positions

# %%
open_auction = OpenAuction(positions)
orders_filtered = create_order_objects(test_orders_converted)
open_auction.add_order(orders_filtered)
open_auction.match_orders(positions)
# Out:
# Matched order: ORDER_10880 (INST_009) and ORDER_1868 (INST_000) for 7000.0 at price 100.0
# Matched order: ORDER_10450 (INST_009) and ORDER_87 (INST_007) for 68.0 at price 100.0
# Matched order: ORDER_10450 (INST_009) and ORDER_8431 (INST_007) for 72.0 at price 100.0
# Matched order: ORDER_10450 (INST_009) and ORDER_426 (INST_003) for 67.0 at price 100.0
# Matched order: ORDER_10450 (INST_009) and ORDER_2439 (INST_001) for 8400.0 at price 100.0
# Matched order: ORDER_10450 (INST_009) and ORDER_2431 (INST_001) for 3900.0 at price 100.0
# Matched order: ORDER_10450 (INST_009) and ORDER_7869 (INST_006) for 61.0 at price 100.0
# Matched order: ORDER_10450 (INST_009) and ORDER_8888 (INST_007) for 86.0 at price 100.0
# Matched order: ORDER_10450 (INST_009) and ORDER_94 (INST_008) for 41000.0 at price 100.0
# Matched order: ORDER_10450 (INST_009) and ORDER_9879 (INST_008) for 56000.0 at price 100.0
# Matched order: ORDER_10450 (INST_009) and ORDER_3443 (INST_002) for 85.0 at price 100.0
# Matched order: ORDER_10450 (INST_009) and ORDER_1865 (INST_000) for 4000.0 at price 100.0
# Matched order: ORDER_10450 (INST_009) and ORDER_35 (INST_002) for 15.0 at price 100.0
# Matched order: ORDER_10450 (INST_009) and ORDER_6874 (INST_005) for 20000.0 at price 100.0
# Matched order: ORDER_10450 (INST_009) and ORDER_213 (INST_001) for 3400.0 at price 100.0
# Matched order: ORDER_10450 (INST_009) and ORDER_3865 (INST_002) for 13.0 at price 100.0
# Matched order: ORDER_10450 (INST_009) and ORDER_45 (INST_003) for 75.0 at price 100.0
# Matched order: ORDER_10450 (INST_009) and ORDER_614 (INST_005) for 48258.0 at price 100.0
# Matched order: ORDER_1020 (INST_009) and ORDER_4865 (INST_003) for 6.0 at price 100.0
# Matched order: ORDER_1020 (INST_009) and ORDER_312 (INST_002) for 2.0 at price 100.0
# Matched order: ORDER_1020 (INST_009) and ORDER_325 (INST_002) for 22.5 at price 100.0
# Matched order: ORDER_1020 (INST_009) and ORDER_4445 (INST_003) for 14.0 at price 100.0
# Matched order: ORDER_1020 (INST_009) and ORDER_828 (INST_007) for 1.0 at price 100.0
# Matched order: ORDER_1020 (INST_009) and ORDER_46 (INST_003) for 87.0 at price 100.0
# Matched order: ORDER_1020 (INST_009) and ORDER_98 (INST_008) for 2000.0 at price 100.0
# Matched order: ORDER_1020 (INST_009) and ORDER_628 (INST_005) for 20000.0 at price 100.0
# Matched order: ORDER_1020 (INST_009) and ORDER_4864 (INST_003) for 118.0 at price 100.0
# Matched order: ORDER_1020 (INST_009) and ORDER_1017 (INST_009) for 35000.0 at price 100.0
# Matched order: ORDER_1020 (INST_009) and ORDER_3447 (INST_002) for 2.0 at price 100.1
# Matched order: ORDER_1020 (INST_009) and ORDER_2869 (INST_001) for 2300.0 at price 100.1
# Matched order: ORDER_1020 (INST_009) and ORDER_4435 (INST_003) for 72.0 at price 100.1
# Matched order: ORDER_1020 (INST_009) and ORDER_5871 (INST_004) for 100.0 at price 100.1
# Matched order: ORDER_1020 (INST_009) and ORDER_9865 (INST_008) for 38275.5 at price 100.1
# Matched order: ORDER_40 (INST_003) and ORDER_10884 (INST_009) for 77.5 at price 100.1
# Matched order: ORDER_10 (INST_000) and ORDER_61 (INST_005) for 17500.0 at price 100.1
# Matched order: ORDER_30 (INST_002) and ORDER_7442 (INST_006) for 30.5 at price 100.1
# Matched order: ORDER_9880 (INST_008) and ORDER_8885 (INST_007) for 250.0 at price 100.1
# Matched order: ORDER_9880 (INST_008) and ORDER_9443 (INST_008) for 2750.0 at price 100.1
# Matched order: ORDER_1880 (INST_000) and ORDER_1458 (INST_000) for 34000.0 at price 100.1
# Matched order: ORDER_1450 (INST_000) and ORDER_10866 (INST_009) for 98000.0 at price 100.1
# Matched order: ORDER_1450 (INST_000) and ORDER_6433 (INST_005) for 79000.0 at price 100.1
# Matched order: ORDER_1450 (INST_000) and ORDER_414 (INST_003) for 27.0 at price 100.1
# Matched order: ORDER_1450 (INST_000) and ORDER_10884 (INST_009) for 2922.5 at price 100.1
# Matched order: ORDER_1450 (INST_000) and ORDER_61 (INST_005) for 17500.0 at price 100.1
# Matched order: ORDER_1450 (INST_000) and ORDER_7442 (INST_006) for 69.5 at price 100.1
# Matched order: ORDER_1450 (INST_000) and ORDER_1458 (INST_000) for 29000.0 at price 100.1
# Matched order: ORDER_1450 (INST_000) and ORDER_4437 (INST_003) for 60.0 at price 100.1
# Matched order: ORDER_1450 (INST_000) and ORDER_729 (INST_006) for 10.0 at price 100.1
# Matched order: ORDER_1450 (INST_000) and ORDER_6889 (INST_005) for 63000.0 at price 100.1
# Matched order: ORDER_1450 (INST_000) and ORDER_9459 (INST_008) for 52000.0 at price 100.1
# Matched order: ORDER_1450 (INST_000) and ORDER_10889 (INST_009) for 28000.0 at price 100.1
# Matched order: ORDER_1450 (INST_000) and ORDER_9863 (INST_008) for 2000.0 at price 100.1
# Matched order: ORDER_1450 (INST_000) and ORDER_10437 (INST_009) for 69000.0 at price 100.1
# Matched order: ORDER_1450 (INST_000) and ORDER_1446 (INST_000) for 93000.0 at price 100.1
# Matched order: ORDER_1450 (INST_000) and ORDER_9876 (INST_008) for 39911.0 at price 100.1
# Matched order: ORDER_120 (INST_000) and ORDER_9876 (INST_008) for 5000.0 at price 100.1
# Matched order: ORDER_80 (INST_007) and ORDER_9876 (INST_008) for 42.5 at price 100.1
# Matched order: ORDER_6430 (INST_005) and ORDER_9876 (INST_008) for 9000.0 at price 100.1
# Matched order: ORDER_60 (INST_005) and ORDER_9876 (INST_008) for 10046.5 at price 100.1
# Matched order: ORDER_60 (INST_005) and ORDER_41 (INST_003) for 72.0 at price 100.2
# Matched order: ORDER_60 (INST_005) and ORDER_7448 (INST_006) for 21.0 at price 100.2
# Matched order: ORDER_60 (INST_005) and ORDER_49 (INST_003) for 60.0 at price 100.2
# Matched order: ORDER_60 (INST_005) and ORDER_1879 (INST_000) for 78000.0 at price 100.2
# Matched order: ORDER_60 (INST_005) and ORDER_419 (INST_003) for 72.0 at price 100.2
# Matched order: ORDER_60 (INST_005) and ORDER_716 (INST_006) for 16.0 at price 100.2
# Matched order: ORDER_60 (INST_005) and ORDER_32 (INST_002) for 17.0 at price 100.2
# Matched order: ORDER_60 (INST_005) and ORDER_221 (INST_001) for 1500.0 at price 100.2
# Matched order: ORDER_60 (INST_005) and ORDER_10877 (INST_009) for 6695.5 at price 100.2
# Matched order: ORDER_10870 (INST_009) and ORDER_118 (INST_000) for 86000.0 at price 100.2
# Matched order: ORDER_10870 (INST_009) and ORDER_5451 (INST_004) for 100.0 at price 100.2
# Matched order: ORDER_10870 (INST_009) and ORDER_821 (INST_007) for 35.0 at price 100.2
# Matched order: ORDER_10870 (INST_009) and ORDER_55 (INST_004) for 10000.0 at price 100.2
# Matched order: ORDER_10870 (INST_009) and ORDER_82 (INST_007) for 37.0 at price 100.2
# Matched order: ORDER_10870 (INST_009) and ORDER_422 (INST_003) for 1.0 at price 100.2
# Matched order: ORDER_10870 (INST_009) and ORDER_10877 (INST_009) for 5827.0 at price 100.2
# Matched order: ORDER_610 (INST_005) and ORDER_5453 (INST_004) for 14000.0 at price 100.2
# Matched order: ORDER_20 (INST_001) and ORDER_8454 (INST_007) for 44.0 at price 100.2
# Matched order: ORDER_20 (INST_001) and ORDER_2436 (INST_001) for 4306.0 at price 100.2
# Matched order: ORDER_10440 (INST_009) and ORDER_1455 (INST_000) for 21000.0 at price 100.2
# Matched order: ORDER_6440 (INST_005) and ORDER_23 (INST_001) for 9000.0 at price 100.2
# Matched order: ORDER_6440 (INST_005) and ORDER_2436 (INST_001) for 4794.0 at price 100.2
# Matched order: ORDER_6440 (INST_005) and ORDER_1455 (INST_000) for 26206.0 at price 100.2
# Matched order: ORDER_9450 (INST_008) and ORDER_6455 (INST_005) for 64000.0 at price 100.2
# Matched order: ORDER_9450 (INST_008) and ORDER_33 (INST_002) for 43.0 at price 100.2
# Matched order: ORDER_9450 (INST_008) and ORDER_1455 (INST_000) for 13794.0 at price 100.2
# Matched order: ORDER_9450 (INST_008) and ORDER_9872 (INST_008) for 71663.0 at price 100.2
# Matched order: ORDER_6880 (INST_005) and ORDER_10872 (INST_009) for 1000.0 at price 100.2
# Matched order: ORDER_6880 (INST_005) and ORDER_2443 (INST_001) for 3100.0 at price 100.2
# Matched order: ORDER_6880 (INST_005) and ORDER_9872 (INST_008) for 3900.0 at price 100.2
# Matched order: ORDER_3880 (INST_002) and ORDER_4443 (INST_003) for 63.0 at price 100.2
# Matched order: ORDER_220 (INST_001) and ORDER_4433 (INST_003) for 92.0 at price 100.2
# Matched order: ORDER_220 (INST_001) and ORDER_9872 (INST_008) for 5308.0 at price 100.2
# Matched order: ORDER_110 (INST_000) and ORDER_1026 (INST_009) for 43000.0 at price 100.2
# Matched order: ORDER_110 (INST_000) and ORDER_4863 (INST_003) for 87.0 at price 100.2
# Matched order: ORDER_110 (INST_000) and ORDER_3867 (INST_002) for 61.0 at price 100.2
# Matched order: ORDER_110 (INST_000) and ORDER_4873 (INST_003) for 35.0 at price 100.2
# Matched order: ORDER_110 (INST_000) and ORDER_9433 (INST_008) for 12000.0 at price 100.2
# Matched order: ORDER_110 (INST_000) and ORDER_6868 (INST_005) for 9817.0 at price 100.3
# Matched order: ORDER_5870 (INST_004) and ORDER_817 (INST_007) for 6.0 at price 100.3
# Matched order: ORDER_5870 (INST_004) and ORDER_9868 (INST_008) for 594.0 at price 100.3
# Matched order: ORDER_2870 (INST_001) and ORDER_1448 (INST_000) for 10200.0 at price 100.3
# Matched order: ORDER_3450 (INST_002) and ORDER_4448 (INST_003) for 72.5 at price 100.3
# Matched order: ORDER_2450 (INST_001) and ORDER_21 (INST_001) for 8500.0 at price 100.3
# Matched order: ORDER_2450 (INST_001) and ORDER_59 (INST_004) for 3700.0 at price 100.3
# Matched order: ORDER_2450 (INST_001) and ORDER_4862 (INST_003) for 43.0 at price 100.3
# Matched order: ORDER_2450 (INST_001) and ORDER_52 (INST_004) for 8900.0 at price 100.3
# Matched order: ORDER_2450 (INST_001) and ORDER_99 (INST_008) for 7.0 at price 100.3
# Matched order: ORDER_10860 (INST_009) and ORDER_914 (INST_008) for 9000.0 at price 100.3
# Matched order: ORDER_10860 (INST_009) and ORDER_3441 (INST_002) for 3.0 at price 100.3
# Matched order: ORDER_10860 (INST_009) and ORDER_423 (INST_003) for 76.0 at price 100.3
# Matched order: ORDER_10860 (INST_009) and ORDER_6871 (INST_005) for 74921.0 at price 100.3
# Matched order: ORDER_320 (INST_002) and ORDER_9871 (INST_008) for 52.0 at price 100.3
# Matched order: ORDER_5860 (INST_004) and ORDER_1454 (INST_000) for 800.0 at price 100.3
# Matched order: ORDER_2880 (INST_001) and ORDER_3442 (INST_002) for 114.0 at price 100.3
# Matched order: ORDER_2880 (INST_001) and ORDER_6872 (INST_005) for 4586.0 at price 100.3
# Matched order: ORDER_6450 (INST_005) and ORDER_4455 (INST_003) for 64.0 at price 100.3
# Matched order: ORDER_6450 (INST_005) and ORDER_725 (INST_006) for 3.5 at price 100.3
# Matched order: ORDER_6450 (INST_005) and ORDER_912 (INST_008) for 60432.5 at price 100.3
# Matched order: ORDER_4880 (INST_003) and ORDER_8455 (INST_007) for 37.0 at price 100.3
# Matched order: ORDER_4880 (INST_003) and ORDER_56 (INST_004) for 2.0 at price 100.3
# Matched order: ORDER_2440 (INST_001) and ORDER_9455 (INST_008) for 7700.0 at price 100.3
# Matched order: ORDER_1440 (INST_000) and ORDER_8456 (INST_007) for 169.0 at price 100.3
# Matched order: ORDER_1440 (INST_000) and ORDER_9436 (INST_008) for 15831.0 at price 100.3
# Matched order: ORDER_4450 (INST_003) and ORDER_9887 (INST_008) for 134.5 at price 100.3
# Matched order: ORDER_420 (INST_003) and ORDER_1014 (INST_009) for 56.0 at price 100.3
# Matched order: ORDER_620 (INST_005) and ORDER_5868 (INST_004) for 19200.0 at price 100.3
# Matched order: ORDER_620 (INST_005) and ORDER_6868 (INST_005) for 2800.0 at price 100.3
# Matched order: ORDER_520 (INST_004) and ORDER_6871 (INST_005) for 8100.0 at price 100.3
# Matched order: ORDER_210 (INST_001) and ORDER_9871 (INST_008) for 7900.0 at price 100.3
# Matched order: ORDER_5880 (INST_004) and ORDER_1454 (INST_000) for 7400.0 at price 100.3
# Matched order: ORDER_1870 (INST_000) and ORDER_912 (INST_008) for 11567.5 at price 100.3
# Matched order: ORDER_1870 (INST_000) and ORDER_56 (INST_004) for 7698.0 at price 100.3
# Matched order: ORDER_1870 (INST_000) and ORDER_9887 (INST_008) for 41865.5 at price 100.3
# Matched order: ORDER_1870 (INST_000) and ORDER_217 (INST_001) for 7000.0 at price 100.3
# Matched order: ORDER_1870 (INST_000) and ORDER_1454 (INST_000) for 10800.0 at price 100.3
# Matched order: ORDER_1870 (INST_000) and ORDER_3869 (INST_002) for 13.0 at price 100.4
# Matched order: ORDER_1870 (INST_000) and ORDER_3878 (INST_002) for 7.0 at price 100.4
# Matched order: ORDER_1870 (INST_000) and ORDER_9874 (INST_008) for 21000.0 at price 100.4
# Matched order: ORDER_1870 (INST_000) and ORDER_6881 (INST_005) for 71000.0 at price 100.4
# Matched order: ORDER_1870 (INST_000) and ORDER_2883 (INST_001) for 3000.0 at price 100.4
# Matched order: ORDER_1870 (INST_000) and ORDER_7877 (INST_006) for 81.0 at price 100.4
# Matched order: ORDER_1870 (INST_000) and ORDER_64 (INST_005) for 8968.0 at price 100.4
# Matched order: ORDER_5450 (INST_004) and ORDER_44 (INST_003) for 20.0 at price 100.4
# Matched order: ORDER_5450 (INST_004) and ORDER_7878 (INST_006) for 30.0 at price 100.4
# Matched order: ORDER_5450 (INST_004) and ORDER_9448 (INST_008) for 36100.0 at price 100.4
# Matched order: ORDER_920 (INST_008) and ORDER_3435 (INST_002) for 386.0 at price 100.4
# Matched order: ORDER_920 (INST_008) and ORDER_6435 (INST_005) for 28614.0 at price 100.4
# Matched order: ORDER_8880 (INST_007) and ORDER_1436 (INST_000) for 63.0 at price 100.4
# Matched order: ORDER_7450 (INST_006) and ORDER_523 (INST_004) for 207.5 at price 100.4
# Matched order: ORDER_3870 (INST_002) and ORDER_2872 (INST_001) for 30.0 at price 100.4
# Matched order: ORDER_720 (INST_006) and ORDER_4453 (INST_003) for 8.0 at price 100.4
# Matched order: ORDER_720 (INST_006) and ORDER_9442 (INST_008) for 18.0 at price 100.4
# Matched order: ORDER_5440 (INST_004) and ORDER_10453 (INST_009) for 11800.0 at price 100.4
# Matched order: ORDER_8450 (INST_007) and ORDER_1011 (INST_009) for 274.5 at price 100.4
# Matched order: ORDER_7880 (INST_006) and ORDER_624 (INST_005) for 30.0 at price 100.4
# Matched order: ORDER_3440 (INST_002) and ORDER_2872 (INST_001) for 50.0 at price 100.4
# Matched order: ORDER_820 (INST_007) and ORDER_2885 (INST_001) for 21.0 at price 100.4
# Matched order: ORDER_310 (INST_002) and ORDER_3885 (INST_002) for 45.0 at price 100.4
# Matched order: ORDER_510 (INST_004) and ORDER_2456 (INST_001) for 1000.0 at price 100.4
# Matched order: ORDER_410 (INST_003) and ORDER_5886 (INST_004) for 78.0 at price 100.4
# Matched order: ORDER_4870 (INST_003) and ORDER_613 (INST_005) for 289.0 at price 100.4
# Matched order: ORDER_4440 (INST_003) and ORDER_2885 (INST_001) for 19.0 at price 100.4
# Matched order: ORDER_1010 (INST_009) and ORDER_428 (INST_003) for 50.0 at price 100.4
# Matched order: ORDER_1010 (INST_009) and ORDER_613 (INST_005) for 6711.0 at price 100.4
# Matched order: ORDER_1010 (INST_009) and ORDER_429 (INST_003) for 58.0 at price 100.4
# Matched order: ORDER_1010 (INST_009) and ORDER_91 (INST_008) for 75181.0 at price 100.4
# Matched order: ORDER_9870 (INST_008) and ORDER_7889 (INST_006) for 100.0 at price 100.4
# Matched order: ORDER_9870 (INST_008) and ORDER_64 (INST_005) for 73032.0 at price 100.4
# Matched order: ORDER_9870 (INST_008) and ORDER_10444 (INST_009) for 85000.0 at price 100.4
# Matched order: ORDER_9870 (INST_008) and ORDER_9448 (INST_008) for 42900.0 at price 100.4
# Matched order: ORDER_9870 (INST_008) and ORDER_3875 (INST_002) for 21.5 at price 100.4
# Matched order: ORDER_9870 (INST_008) and ORDER_10431 (INST_009) for 27000.0 at price 100.4
# Matched order: ORDER_9870 (INST_008) and ORDER_3438 (INST_002) for 34.0 at price 100.4
# Matched order: ORDER_9870 (INST_008) and ORDER_523 (INST_004) for 6292.5 at price 100.4
# Matched order: ORDER_9870 (INST_008) and ORDER_7446 (INST_006) for 72.0 at price 100.4
# Matched order: ORDER_9870 (INST_008) and ORDER_2872 (INST_001) for 6548.0 at price 100.4
# Matched order: ORDER_9440 (INST_008) and ORDER_5438 (INST_004) for 13300.0 at price 100.4
# Matched order: ORDER_9440 (INST_008) and ORDER_5886 (INST_004) for 5022.0 at price 100.4
# Matched order: ORDER_9440 (INST_008) and ORDER_928 (INST_008) for 7678.0 at price 100.5
# Matched order: ORDER_810 (INST_007) and ORDER_928 (INST_008) for 87.0 at price 100.5
# Matched order: ORDER_7860 (INST_006) and ORDER_928 (INST_008) for 11.0 at price 100.5
# Matched order: ORDER_6860 (INST_005) and ORDER_8438 (INST_007) for 29.0 at price 100.5
# Matched order: ORDER_6860 (INST_005) and ORDER_9877 (INST_008) for 61000.0 at price 100.5
# Matched order: ORDER_6860 (INST_005) and ORDER_4432 (INST_003) for 88.0 at price 100.5
# Matched order: ORDER_6860 (INST_005) and ORDER_919 (INST_008) for 9883.0 at price 100.5
# Matched order: ORDER_1860 (INST_000) and ORDER_819 (INST_007) for 18.0 at price 100.5
# Matched order: ORDER_1860 (INST_000) and ORDER_919 (INST_008) for 13117.0 at price 100.5
# Matched order: ORDER_1860 (INST_000) and ORDER_31 (INST_002) for 31.0 at price 100.5
# Matched order: ORDER_1860 (INST_000) and ORDER_6459 (INST_005) for 32834.0 at price 100.5
# Matched order: ORDER_7870 (INST_006) and ORDER_7871 (INST_006) for 36.0 at price 100.5
# Matched order: ORDER_6870 (INST_005) and ORDER_6459 (INST_005) for 31166.0 at price 100.5
# Matched order: ORDER_6870 (INST_005) and ORDER_7871 (INST_006) for 8.0 at price 100.5
# Matched order: ORDER_6870 (INST_005) and ORDER_3431 (INST_002) for 96.0 at price 100.5
# Matched order: ORDER_6870 (INST_005) and ORDER_5881 (INST_004) for 2000.0 at price 100.5
# Matched order: ORDER_6870 (INST_005) and ORDER_621 (INST_005) for 9730.0 at price 100.5
# Matched order: ORDER_7440 (INST_006) and ORDER_921 (INST_008) for 65.0 at price 100.5
# Matched order: ORDER_710 (INST_006) and ORDER_823 (INST_007) for 26.0 at price 100.5
# Matched order: ORDER_710 (INST_006) and ORDER_10883 (INST_009) for 74.0 at price 100.5
# Matched order: ORDER_910 (INST_008) and ORDER_10883 (INST_009) for 3926.0 at price 100.5
# Matched order: ORDER_910 (INST_008) and ORDER_512 (INST_004) for 7100.0 at price 100.5
# Matched order: ORDER_910 (INST_008) and ORDER_925 (INST_008) for 5500.0 at price 100.5
# Matched order: ORDER_910 (INST_008) and ORDER_3456 (INST_002) for 231.0 at price 100.5
# Matched order: ORDER_910 (INST_008) and ORDER_6885 (INST_005) for 22243.0 at price 100.5
# Matched order: ORDER_8870 (INST_007) and ORDER_816 (INST_007) for 31.0 at price 100.5
# Matched order: ORDER_8870 (INST_007) and ORDER_522 (INST_004) for 112.0 at price 100.6
# Matched order: ORDER_8440 (INST_007) and ORDER_4434 (INST_003) for 29.0 at price 100.6
# Matched order: ORDER_3860 (INST_002) and ORDER_10868 (INST_009) for 76.0 at price 100.6
# Matched order: ORDER_7430 (INST_006) and ORDER_522 (INST_004) for 34.0 at price 100.6
# Matched order: ORDER_3430 (INST_002) and ORDER_618 (INST_005) for 89.0 at price 100.6
# Matched order: ORDER_70 (INST_006) and ORDER_522 (INST_004) for 84.5 at price 100.6
# Matched order: ORDER_10430 (INST_009) and ORDER_618 (INST_005) for 19911.0 at price 100.6
# Matched order: ORDER_10430 (INST_009) and ORDER_1449 (INST_000) for 27089.0 at price 100.6
# Matched order: ORDER_90 (INST_008) and ORDER_522 (INST_004) for 969.5 at price 100.6
# Matched order: ORDER_90 (INST_008) and ORDER_69 (INST_005) for 73000.0 at price 100.6
# Matched order: ORDER_90 (INST_008) and ORDER_73 (INST_006) for 41.0 at price 100.6
# Matched order: ORDER_90 (INST_008) and ORDER_5889 (INST_004) for 3800.0 at price 100.6
# Matched order: ORDER_90 (INST_008) and ORDER_129 (INST_000) for 4689.5 at price 100.6
# Matched order: ORDER_5430 (INST_004) and ORDER_6432 (INST_005) for 1500.0 at price 100.6
# Matched order: ORDER_1430 (INST_000) and ORDER_514 (INST_004) for 1000.0 at price 100.6
# Matched order: ORDER_1430 (INST_000) and ORDER_5874 (INST_004) for 2000.0 at price 100.6
# Matched order: ORDER_4430 (INST_003) and ORDER_129 (INST_000) for 100.0 at price 100.6
# Matched order: ORDER_8860 (INST_007) and ORDER_6432 (INST_005) for 20.0 at price 100.6
# Matched order: ORDER_2860 (INST_001) and ORDER_5885 (INST_004) for 2700.0 at price 100.6
# Matched order: ORDER_8430 (INST_007) and ORDER_5885 (INST_004) for 21.0 at price 100.6
# Matched order: ORDER_100 (INST_009) and ORDER_8432 (INST_007) for 74.0 at price 100.6
# Matched order: ORDER_100 (INST_009) and ORDER_3452 (INST_002) for 8.0 at price 100.6
# Matched order: ORDER_100 (INST_009) and ORDER_4452 (INST_003) for 62.0 at price 100.6
# Matched order: ORDER_100 (INST_009) and ORDER_7882 (INST_006) for 88.0 at price 100.6
# Matched order: ORDER_100 (INST_009) and ORDER_6453 (INST_005) for 7268.0 at price 100.6
# Matched order: ORDER_9430 (INST_008) and ORDER_8883 (INST_007) for 48.0 at price 100.6
# Matched order: ORDER_9430 (INST_008) and ORDER_1872 (INST_000) for 952.0 at price 100.6
# Matched order: ORDER_2430 (INST_001) and ORDER_3454 (INST_002) for 2.0 at price 100.6
# Matched order: ORDER_2430 (INST_001) and ORDER_1885 (INST_000) for 8698.0 at price 100.6
# Matched order: ORDER_50 (INST_004) and ORDER_1872 (INST_000) for 2850.0 at price 100.6
# Matched order: ORDER_9860 (INST_008) and ORDER_5455 (INST_004) for 3500.0 at price 100.6
# Matched order: ORDER_9860 (INST_008) and ORDER_113 (INST_000) for 23500.0 at price 100.6
# Matched order: ORDER_4860 (INST_003) and ORDER_1886 (INST_000) for 87.0 at price 100.6
# ('100.6',
#  {'CLIENT_107': {'INST_001': 0,
#    'INST_005': -40000.0,
#    'INST_009': 0,
#    'INST_002': 152.0,
#    'INST_004': 0,
#    'INST_003': 0,
#    'INST_000': 0,
#    'INST_007': 0,
#    'INST_008': -112213.0,
#    'INST_006': 0},
#   'CLIENT_111': {'INST_001': 9400.0,
#    'INST_005': -9172.0,
#    'INST_009': 0.0,
#    'INST_002': -507.0,
#    'INST_004': 0.0,
#    'INST_003': -152.0,
#    'INST_000': 0,
#    'INST_007': -54.0,
#    'INST_008': 0.0,
#    'INST_006': 0},
#   'CLIENT_113': {'INST_001': 0,
#    'INST_005': 0.0,
#    'INST_009': 168000.0,
#    'INST_002': 0.0,
#    'INST_004': 0,
#    'INST_003': 156.0,
#    'INST_000': 0.0,
#    'INST_007': 0,
#    'INST_008': 0,
#    'INST_006': 74.0},
#   'CLIENT_106': {'INST_001': 0,
#    'INST_005': 0.0,
#    'INST_009': 0,
#    'INST_002': 104.0,
#    'INST_004': 0,
#    'INST_003': 0,
#    'INST_000': 0.0,
#    'INST_007': 0.0,
#    'INST_008': 0.0,
#    'INST_006': 0},
#   'CLIENT_103': {'INST_001': 17400.0,
#    'INST_005': 28000.0,
#    'INST_009': 0.0,
#    'INST_002': -232.0,
#    'INST_004': 0.0,
#    'INST_003': -174.0,
#    'INST_000': 130000.0,
#    'INST_007': 216.0,
#    'INST_008': 0,
#    'INST_006': 0.0},
#   'CLIENT_101': {'INST_001': 5400.0,
#    'INST_005': 0,
#    'INST_009': 0,
#    'INST_002': -6.0,
#    'INST_004': 16200.0,
#    'INST_003': 0.0,
#    'INST_000': -71748.0,
#    'INST_007': 0.0,
#    'INST_008': 0.0,
#    'INST_006': 0},
#   'CLIENT_102': {'INST_001': 0,
#    'INST_005': 0,
#    'INST_009': 204000.0,
#    'INST_002': 0,
#    'INST_004': 0.0,
#    'INST_003': -186.0,
#    'INST_000': 0,
#    'INST_007': 0,
#    'INST_008': 0.0,
#    'INST_006': 0.0},
#   'CLIENT_105': {'INST_001': 0.0,
#    'INST_005': -25234.0,
#    'INST_009': -112.0,
#    'INST_002': 268.0,
#    'INST_004': -24600.0,
#    'INST_003': 0,
#    'INST_000': 0.0,
#    'INST_007': 0.0,
#    'INST_008': -36.0,
#    'INST_006': 0},
#   'CLIENT_109': {'INST_001': 0.0,
#    'INST_005': -44486.0,
#    'INST_009': 0.0,
#    'INST_002': 0,
#    'INST_004': -42200.0,
#    'INST_003': -28.0,
#    'INST_000': 0.0,
#    'INST_007': -338.0,
#    'INST_008': 40000.0,
#    'INST_006': 0.0},
#   'CLIENT_100': {'INST_001': 0,
#    'INST_005': -122042.0,
#    'INST_009': 0.0,
#    'INST_002': -4.0,
#    'INST_004': 0,
#    'INST_003': 286.0,
#    'INST_000': 0.0,
#    'INST_007': 0,
#    'INST_008': 0.0,
#    'INST_006': 0.0},
#   'CLIENT_114': {'INST_001': 0.0,
#    'INST_005': 0,
#    'INST_009': 0,
#    'INST_002': -772.0,
#    'INST_004': -5442.0,
#    'INST_003': 0.0,
#    'INST_000': 0,
#    'INST_007': -332.0,
#    'INST_008': 0.0,
#    'INST_006': 0},
#   'CLIENT_110': {'INST_001': 0,
#    'INST_005': 0,
#    'INST_009': 0,
#    'INST_002': -90.0,
#    'INST_004': 0,
#    'INST_003': -230.0,
#    'INST_000': 32000.0,
#    'INST_007': 0,
#    'INST_008': 114096.0,
#    'INST_006': 0.0},
#   'CLIENT_112': {'INST_001': -2000.0,
#    'INST_005': 0,
#    'INST_009': -8000.0,
#    'INST_002': -4.0,
#    'INST_004': -38600.0,
#    'INST_003': 0.0,
#    'INST_000': 0,
#    'INST_007': 0,
#    'INST_008': -21052.0,
#    'INST_006': 0.0},
#   'CLIENT_108': {'INST_001': -4680.0,
#    'INST_005': -57228.0,
#    'INST_009': -70000.0,
#    'INST_002': -122.0,
#    'INST_004': -10200.0,
#    'INST_003': 0.0,
#    'INST_000': -126.0,
#    'INST_007': 0,
#    'INST_008': -5000.0,
#    'INST_006': 200.0},
#   'CLIENT_104': {'INST_001': 15800.0,
#    'INST_005': -40000.0,
#    'INST_009': -152.0,
#    'INST_002': 0.0,
#    'INST_004': 0.0,
#    'INST_003': -198.0,
#    'INST_000': 0,
#    'INST_007': 0.0,
#    'INST_008': -24000.0,
#    'INST_006': 0}})

# %%
open_auction.match_price
# Out:
# '100.6'

# %%
order_instrument_dict = {}
for new_order in orders_filtered:
  if new_order.instrument not in order_instrument_dict:
    order_instrument_dict[new_order.instrument] = {"current_price":0,"bid":[],"ask":[]}
    order_instrument_dict[new_order.instrument]['current_price'] = open_auction.match_price

  if new_order.quantity == 0:
    continue

  if new_order.side == 'Sell':
    order_instrument_dict[new_order.instrument]['ask'].append(new_order)

  else:
    order_instrument_dict[new_order.instrument]['bid'].append(new_order)

# %%
# order_instrument_dict

# %%
# positions

# %% [markdown]
# ## **Continuous Trading**

# %%
import pandas as pd
from datetime import datetime

example_clients_df = pd.read_csv("/content/drive/MyDrive/BoA 2024/Data/example/input_clients.csv")
example_instruments_df = pd.read_csv("/content/drive/MyDrive/BoA 2024/Data/example/input_instruments.csv")
example_orders_df = pd.read_csv("/content/drive/MyDrive/BoA 2024/Data/example/input_orders.csv")

test_clients_df = pd.read_csv("/content/drive/MyDrive/BoA 2024/Data/test/input_clients.csv")
test_instruments_df = pd.read_csv("/content/drive/MyDrive/BoA 2024/Data/test/input_instruments.csv")
test_orders_df = pd.read_csv("/content/drive/MyDrive/BoA 2024/Data/test/input_orders.csv")

test_orders_list = list(map(lambda x:Order(order_id=x[1], timestamp=x[0], instrument=x[2], price=x[5], quantity=x[3], side=x[6], client=x[4]), test_orders_df.values.tolist()))
# test_orders_list = list(map(lambda x:Order(order_id=x[1], timestamp=x[0], instrument=x[2], price=x[5], quantity=x[3], side=x[6], client=x[4]), example_orders_df.values.tolist()))
for index, ele in enumerate(test_orders_list):
  test_orders_list[index].timeobject = datetime.strptime(test_orders_list[index].timestamp, '%H:%M:%S')
test_orders_list.sort(key=lambda order: order.timeobject)

test_instruments_list = list(map(lambda x:Instrument(instrumentID=x[0], currency=x[1], lotsize=x[2]), test_instruments_df.values.tolist()))
# test_instruments_list = list(map(lambda x:Instrument(instrumentID=x[0], currency=x[1], lotsize=x[2]), example_instruments_df.values.tolist()))
test_instruments_dict = {}
for instru in test_instruments_list:
  test_instruments_dict[instru.instrumentID] = instru

test_clients_list = list(map(lambda x:Client(clientID=x[0], currencies=x[1], position_check=x[2], rating=x[3]), test_clients_df.values.tolist()))
# test_clients_list = list(map(lambda x:Client(clientID=x[0], currencies=x[1], position_check=x[2], rating=x[3]), example_clients_df.values.tolist()))
test_client_dict = {}
for client in test_clients_list:
  test_client_dict[client.clientID] = client

invalid_orders = {"Order Id": [], "Rejection Reason": []}

# Filter out orders before 930am..


# ask list sorted by price, lowest to highest
# bid list sorted by price, highest to lowest
def sort_price_list(curr_list, reverse=False):
  return sorted(curr_list, key=lambda ele: ele.price, reverse=reverse)

client_position = {}
for client in test_clients_list:
  client_position[client.clientID] = {}
  for instrument in test_instruments_list:
    client_position[client.clientID][instrument.instrumentID] = 0

order_instrument_dict = {}
for new_order in test_orders_list:
  # Policy check
  if new_order.instrument not in test_instruments_dict:
    invalid_orders["Order Id"].append(new_order.order_id)
    invalid_orders["Rejection Reason"].append("REJECTED – INSTRUMENT NOT FOUND")
    continue
  # Currency check
  current_client = test_client_dict[new_order.client]
  client_currencies = current_client.currencies.split(",")
  if test_instruments_dict[new_order.instrument].currency not in client_currencies:
    invalid_orders["Order Id"].append(new_order.order_id)
    invalid_orders["Rejection Reason"].append("REJECTED – MISMATCH CURRENCY")
    continue

  if new_order.instrument not in order_instrument_dict:
    order_instrument_dict[new_order.instrument] = {"current_price":0,"bid":[],"ask":[]}
    # Skip market order since no previous prices
    if new_order.price == "Market":
      order_instrument_dict[new_order.instrument]["bid" if new_order.side == "Buy" else "ask"].append(new_order)
      continue

  # Check lot size
  if new_order.quantity % test_instruments_dict[new_order.instrument].lotsize != 0:
    invalid_orders["Order Id"].append(new_order.order_id)
    invalid_orders["Rejection Reason"].append("REJECTED – INVALID LOT SIZE")
    continue

  bought = False
  if new_order.side == "Buy":
    # Check existing ask orders
    while not bought and len(order_instrument_dict[new_order.instrument]["ask"]) > 0:
      ask_order = order_instrument_dict[new_order.instrument]["ask"].pop(0)
      # Can buy?
      # print(ask_order.quantity, new_order.price)
      if new_order.price != "Market":
        if ask_order.price != "Market" and ask_order.price > new_order.price:
          order_instrument_dict[new_order.instrument]["ask"].append(ask_order)
          break

      # Check the quantity
      # print("BUYING")
      if new_order.quantity <= ask_order.quantity:
        bought = True
        client_position[new_order.client][ask_order.instrument] += new_order.quantity # Add into position
        client_position[ask_order.client][ask_order.instrument] -= new_order.quantity # Add into position
        ask_order.quantity -= new_order.quantity
        # Add back if still have
        if ask_order.quantity > 0:
          order_instrument_dict[new_order.instrument]["ask"].append(ask_order)
      else:
        new_order.quantity -= ask_order.quantity
        client_position[new_order.client][ask_order.instrument] += ask_order.quantity # Add into position
        client_position[ask_order.client][ask_order.instrument] -= ask_order.quantity # Add into position

    # Cannot buy, add into bids
    if not bought:
      order_instrument_dict[new_order.instrument]["bid"].append(new_order)
  else:
    # Check existing bid orders
    for bid_index in range(len(order_instrument_dict[new_order.instrument]["bid"])):
      bid_order = order_instrument_dict[new_order.instrument]["bid"][bid_index]

      if new_order.price != "Market":
        # Can sell?
        if bid_order.price != "Market" and bid_order.price < new_order.price:
          continue
        # Cannot short sell
        if new_order.instrument not in client_position[new_order.client] and test_client_dict[new_order.client].position_check == "Y":
          invalid_orders["Order Id"].append(new_order.order_id)
          invalid_orders["Rejection Reason"].append("REJECTED – POSITION CHECK FAILED")
          continue

      # print("SELLING")
      # Check the quantity
      if new_order.quantity <= bid_order.quantity:
        bought = True
        client_position[new_order.client][bid_order.instrument] -= new_order.quantity # Add into position
        client_position[bid_order.client][bid_order.instrument] += new_order.quantity # Add into position
        bid_order.quantity -= new_order.quantity
        # Remove bid order
        if bid_order.quantity == 0:
          order_instrument_dict[new_order.instrument]["bid"].pop(bid_index)
        else:
          # Update element
          order_instrument_dict[new_order.instrument]["bid"][bid_index] = bid_order
      else:
        new_order.quantity -= bid_order.quantity
        # remove bid order
        order_instrument_dict[new_order.instrument]["bid"].pop(bid_index)
        client_position[new_order.client][bid_order.instrument] -= bid_order.quantity # Add into position
        client_position[bid_order.client][bid_order.instrument] += bid_order.quantity # Add into position
      break

    # Cannot buy, add into ask
    if not bought:
      order_instrument_dict[new_order.instrument]["ask"].append(new_order)

  # Sort bid and ask lists
  order_instrument_dict[new_order.instrument]["bid"] = sort_price_list(order_instrument_dict[new_order.instrument]["bid"])
  order_instrument_dict[new_order.instrument]["ask"] = sort_price_list(order_instrument_dict[new_order.instrument]["ask"], reverse=True)

# print(order_instrument_dict)
# print(client_position)
print(invalid_orders)

# A 2300
# B -5800
# C 4300
# E -800
# Out:
# {'Order Id': ['ORDER_10', 'ORDER_20', 'ORDER_30', 'ORDER_40', 'ORDER_50', 'ORDER_60', 'ORDER_70', 'ORDER_80', 'ORDER_90', 'ORDER_100', 'ORDER_1875', 'ORDER_2875', 'ORDER_3875', 'ORDER_4875', 'ORDER_5875', 'ORDER_6875', 'ORDER_7875', 'ORDER_8875', 'ORDER_9875', 'ORDER_10875', 'ORDER_1450', 'ORDER_2450', 'ORDER_3450', 'ORDER_4450', 'ORDER_5450', 'ORDER_6450', 'ORDER_7450', 'ORDER_8450', 'ORDER_9450', 'ORDER_10450', 'ORDER_125', 'ORDER_1455', 'ORDER_225', 'ORDER_2455', 'ORDER_325', 'ORDER_3455', 'ORDER_425', 'ORDER_4455', 'ORDER_525', 'ORDER_5455', 'ORDER_625', 'ORDER_6455', 'ORDER_725', 'ORDER_7455', 'ORDER_825', 'ORDER_8455', 'ORDER_925', 'ORDER_9455', 'ORDER_1025', 'ORDER_10455', 'ORDER_135', 'ORDER_235', 'ORDER_335', 'ORDER_435', 'ORDER_535', 'ORDER_635', 'ORDER_735', 'ORDER_835', 'ORDER_935', 'ORDER_1035', 'ORDER_1900', 'ORDER_2900', 'ORDER_3900', 'ORDER_4900', 'ORDER_5900', 'ORDER_6900', 'ORDER_7900', 'ORDER_8900', 'ORDER_9900', 'ORDER_10900', 'ORDER_1475', 'ORDER_2475', 'ORDER_3475', 'ORDER_4475', 'ORDER_5475', 'ORDER_6475', 'ORDER_7475', 'ORDER_8475', 'ORDER_9475', 'ORDER_10475', 'ORDER_150', 'ORDER_1910', 'ORDER_250', 'ORDER_2910', 'ORDER_350', 'ORDER_3910', 'ORDER_450', 'ORDER_4910', 'ORDER_550', 'ORDER_5910', 'ORDER_650', 'ORDER_6910', 'ORDER_750', 'ORDER_7910', 'ORDER_850', 'ORDER_8910', 'ORDER_950', 'ORDER_9910', 'ORDER_1050', 'ORDER_10910', 'ORDER_1490', 'ORDER_2490', 'ORDER_3490', 'ORDER_4490', 'ORDER_5490', 'ORDER_6490', 'ORDER_7490', 'ORDER_8490', 'ORDER_9490', 'ORDER_10490', 'ORDER_1925', 'ORDER_2925', 'ORDER_3925', 'ORDER_4925', 'ORDER_5925', 'ORDER_6925', 'ORDER_7925', 'ORDER_8925', 'ORDER_9925', 'ORDER_10925', 'ORDER_170', 'ORDER_1500', 'ORDER_270', 'ORDER_2500', 'ORDER_370', 'ORDER_3500', 'ORDER_470', 'ORDER_4500', 'ORDER_570', 'ORDER_5500', 'ORDER_670', 'ORDER_6500', 'ORDER_770', 'ORDER_7500', 'ORDER_870', 'ORDER_8500', 'ORDER_970', 'ORDER_9500', 'ORDER_1070', 'ORDER_10500', 'ORDER_175', 'ORDER_275', 'ORDER_375', 'ORDER_475', 'ORDER_575', 'ORDER_675', 'ORDER_775', 'ORDER_875', 'ORDER_975', 'ORDER_1075', 'ORDER_1945', 'ORDER_2945', 'ORDER_3945', 'ORDER_4945', 'ORDER_5945', 'ORDER_6945', 'ORDER_7945', 'ORDER_8945', 'ORDER_9945', 'ORDER_10945', 'ORDER_1950', 'ORDER_2950', 'ORDER_3950', 'ORDER_4950', 'ORDER_5950', 'ORDER_6950', 'ORDER_7950', 'ORDER_8950', 'ORDER_9950', 'ORDER_10950', 'ORDER_1525', 'ORDER_2525', 'ORDER_3525', 'ORDER_4525', 'ORDER_5525', 'ORDER_6525', 'ORDER_7525', 'ORDER_8525', 'ORDER_9525', 'ORDER_10525', 'ORDER_1100', 'ORDER_2100', 'ORDER_3100', 'ORDER_4100', 'ORDER_5100', 'ORDER_6100', 'ORDER_7100', 'ORDER_8100', 'ORDER_9100', 'ORDER_10100', 'ORDER_1105', 'ORDER_2105', 'ORDER_3105', 'ORDER_4105', 'ORDER_5105', 'ORDER_6105', 'ORDER_7105', 'ORDER_8105', 'ORDER_9105', 'ORDER_10105', 'ORDER_1975', 'ORDER_2975', 'ORDER_3975', 'ORDER_4975', 'ORDER_5975', 'ORDER_6975', 'ORDER_7975', 'ORDER_8975', 'ORDER_9975', 'ORDER_10975', 'ORDER_1550', 'ORDER_1980', 'ORDER_2550', 'ORDER_2980', 'ORDER_3550', 'ORDER_3980', 'ORDER_4550', 'ORDER_4980', 'ORDER_5550', 'ORDER_5980', 'ORDER_6550', 'ORDER_6980', 'ORDER_7550', 'ORDER_7980', 'ORDER_8550', 'ORDER_8980', 'ORDER_9550', 'ORDER_9980', 'ORDER_10550', 'ORDER_10980', 'ORDER_1125', 'ORDER_2125', 'ORDER_3125', 'ORDER_4125', 'ORDER_5125', 'ORDER_6125', 'ORDER_7125', 'ORDER_8125', 'ORDER_9125', 'ORDER_10125', 'ORDER_1560', 'ORDER_2560', 'ORDER_3560', 'ORDER_4560', 'ORDER_5560', 'ORDER_6560', 'ORDER_7560', 'ORDER_8560', 'ORDER_9560', 'ORDER_10560', 'ORDER_1140', 'ORDER_2140', 'ORDER_3140', 'ORDER_4140', 'ORDER_5140', 'ORDER_6140', 'ORDER_7140', 'ORDER_8140', 'ORDER_9140', 'ORDER_10140', 'ORDER_1575', 'ORDER_2575', 'ORDER_3575', 'ORDER_4575', 'ORDER_5575', 'ORDER_6575', 'ORDER_7575', 'ORDER_8575', 'ORDER_9575', 'ORDER_10575', 'ORDER_1150', 'ORDER_2150', 'ORDER_3150', 'ORDER_4150', 'ORDER_5150', 'ORDER_6150', 'ORDER_7150', 'ORDER_8150', 'ORDER_9150', 'ORDER_10150', 'ORDER_1595', 'ORDER_2595', 'ORDER_3595', 'ORDER_4595', 'ORDER_5595', 'ORDER_6595', 'ORDER_7595', 'ORDER_859 ...

# %% [markdown]
# ## **Closing Auction**

# %%
test_orders_converted_close = test_orders_df.copy()
test_orders_converted_close['Time'] = pd.to_datetime(test_orders_converted_close['Time'], format='%H:%M:%S', errors='coerce')
test_orders_converted_close = test_orders_converted_close[test_orders_converted_close['Time'].dt.time > pd.to_datetime('16:00:00').time()]
test_orders_converted_close
# Out:
#                     Time      OrderID Instrument  Quantity      Client  Price  \
# 9820 1900-01-01 16:01:00   ORDER_1421   INST_000   99000.0  CLIENT_104   99.7
# 9821 1900-01-01 16:01:00   ORDER_1851   INST_000   95000.0  CLIENT_103  100.7
# 9822 1900-01-01 16:01:00   ORDER_2421   INST_001    1400.0  CLIENT_104  100.2
# 9823 1900-01-01 16:01:00   ORDER_2851   INST_001    8900.0  CLIENT_105  100.1
# 9824 1900-01-01 16:01:00   ORDER_3421   INST_002     100.0  CLIENT_108  100.8
# ...                  ...          ...        ...       ...         ...    ...
# 9995 1900-01-01 16:09:00   ORDER_8859   INST_007      62.0  CLIENT_104   99.6
# 9996 1900-01-01 16:09:00   ORDER_9429   INST_008   59000.0  CLIENT_112  100.1
# 9997 1900-01-01 16:09:00   ORDER_9859   INST_008   94000.0  CLIENT_109  100.9
# 9998 1900-01-01 16:09:00  ORDER_10429   INST_009   31000.0  CLIENT_105  100.1
# 9999 1900-01-01 16:09:00  ORDER_10859   INST_009   46000.0  CLIENT_104   99.4
#
#       Side
# 9820  Sell
# 9821   Buy
# 9822  Sell
# 9823   Buy
# 9824  Sell
# ...    ...
# 9995  Sell
# 9996   Buy
# 9997   Buy
# 9998  Sell
# 9999  Sell
#
# [180 rows x 7 columns]

# %%
test_orders_close = create_order_objects(test_orders_converted_close)
test_orders_close
# Out:
# [<__main__.Order at 0x7e3b6e902fb0>,
#  <__main__.Order at 0x7e3b6e900040>,
#  <__main__.Order at 0x7e3b6e9033d0>,
#  <__main__.Order at 0x7e3b6e903dc0>,
#  <__main__.Order at 0x7e3b6e9030d0>,
#  <__main__.Order at 0x7e3b6e903010>,
#  <__main__.Order at 0x7e3b6e903fa0>,
#  <__main__.Order at 0x7e3b6e903760>,
#  <__main__.Order at 0x7e3b6e902fe0>,
#  <__main__.Order at 0x7e3b6e903460>,
#  <__main__.Order at 0x7e3b6e903490>,
#  <__main__.Order at 0x7e3b6e9034c0>,
#  <__main__.Order at 0x7e3b6e903c40>,
#  <__main__.Order at 0x7e3b6e903b80>,
#  <__main__.Order at 0x7e3b6e903b50>,
#  <__main__.Order at 0x7e3b6e903670>,
#  <__main__.Order at 0x7e3b6e9036d0>,
#  <__main__.Order at 0x7e3b6e903df0>,
#  <__main__.Order at 0x7e3b6e903340>,
#  <__main__.Order at 0x7e3b6e903d00>,
#  <__main__.Order at 0x7e3b6e903b20>,
#  <__main__.Order at 0x7e3b6e903f40>,
#  <__main__.Order at 0x7e3b6e903130>,
#  <__main__.Order at 0x7e3b6e903040>,
#  <__main__.Order at 0x7e3b6e9032e0>,
#  <__main__.Order at 0x7e3b6e903400>,
#  <__main__.Order at 0x7e3b6e903fd0>,
#  <__main__.Order at 0x7e3b6e903070>,
#  <__main__.Order at 0x7e3b6ea02d10>,
#  <__main__.Order at 0x7e3b6ea02d70>,
#  <__main__.Order at 0x7e3b6ea02dd0>,
#  <__main__.Order at 0x7e3b6ea030a0>,
#  <__main__.Order at 0x7e3b6ea03010>,
#  <__main__.Order at 0x7e3b6ea03940>,
#  <__main__.Order at 0x7e3b6ea02bf0>,
#  <__main__.Order at 0x7e3b6ea02560>,
#  <__main__.Order at 0x7e3b6ea027d0>,
#  <__main__.Order at 0x7e3b6ea02590>,
#  <__main__.Order at 0x7e3b6ea02350>,
#  <__main__.Order at 0x7e3b6ea02140>,
#  <__main__.Order at 0x7e3b6ea01a20>,
#  <__main__.Order at 0x7e3b6ea01cc0>,
#  <__main__.Order at 0x7e3b6ea024a0>,
#  <__main__.Order at 0x7e3b6ea01b70>,
#  <__main__.Order at 0x7e3b6ea01ff0>,
#  <__main__.Order at 0x7e3b6ea02020>,
#  <__main__.Order at 0x7e3b6ea01d80>,
#  <__main__.Order at 0x7e3b6ea02110>,
#  <__main__.Order at 0x7e3b6ea021d0>,
#  <__main__.Order at 0x7e3b6ea016c0>,
#  <__main__.Order at 0x7e3b6ea00d00>,
#  <__main__.Order at 0x7e3b6ea00fd0>,
#  <__main__.Order at 0x7e3b6ea01a80>,
#  <__main__.Order at 0x7e3b6ea00e80>,
#  <__main__.Order at 0x7e3b6ea01090>,
#  <__main__.Order at 0x7e3b6ea01270>,
#  <__main__.Order at 0x7e3b6ea01030>,
#  <__main__.Order at 0x7e3b6ea012d0>,
#  <__main__.Order at 0x7e3b6ea019f0>,
#  <__main__.Order at 0x7e3b6ea007c0>,
#  <__main__.Order at 0x7e3b6ea00880>,
#  <__main__.Order at 0x7e3b6ea00580>,
#  <__main__.Order at 0x7e3b6ea00d90>,
#  <__main__.Order at 0x7e3b6ea00670>,
#  <__main__.Order at 0x7e3b6ea00700>,
#  <__main__.Order at 0x7e3b6ea03e80>,
#  <__main__.Order at 0x7e3b6ea03220>,
#  <__main__.Order at 0x7e3b6ea00250>,
#  <__main__.Order at 0x7e3b6ea03190>,
#  <__main__.Order at 0x7e3b6ea03f70>,
#  <__main__.Order at 0x7e3b6ea03f40>,
#  <__main__.Order at 0x7e3b6ea034c0>,
#  <__main__.Order at 0x7e3b6ea00160>,
#  <__main__.Order at 0x7e3b6ea03580>,
#  <__main__.Order at 0x7e3b6ea031f0>,
#  <__main__.Order at 0x7e3b6ea032e0>,
#  <__main__.Order at 0x7e3b6ea003a0>,
#  <__main__.Order at 0x7e3b6ea00490>,
#  <__main__.Order at 0x7e3b6ea00640>,
#  <__main__.Order at 0x7e3b6ea00130>,
#  <__main__.Order at 0x7e3b6ea02d40>,
#  <__main__.Order at 0x7e3b6ea02680>,
#  <__main__.Order at 0x7e3b6ea03bb0>,
#  <__main__.Order at 0x7e3b6ea02920>,
#  <__main__.Order at 0x7e3b6ea02c50>,
#  <__main__.Order at 0x7e3b6ea034f0>,
#  <__main__.Order at 0x7e3b6ea02da0>,
#  <__main__.Order at 0x7e3b6ea02e60>,
#  <__main__.Order at 0x7e3b6ea02e30>,
#  <__main__.Order at 0x7e3b6ea02ec0>,
#  <__main__.Order at 0x7e3b6e91e440>,
#  <__main__.Order at 0x7e3b6e91cf40>,
#  <__main__.Order at 0x7e3b6e91ef50>,
#  <__main__.Order at 0x7e3b6e91e200>,
#  <__main__.Order at 0x7e3b6e91e0e0>,
#  <__main__.Order at 0x7e3b6e91d810>,
#  <__main__.Order at 0x7e3b6e91dab0>,
#  <__main__.Order at 0x7e3b6e91e7a0>,
#  <__main__.Order at 0x7e3b6e91d900>,
#  <__main__.Order at 0x7e3b6e91e230>,
#  <__main__.Order at 0x7e3b6e91d330>,
#  <__main__.Order at 0x7e3b6e91e830>,
#  <__main__.Order at 0x7e3b6e91ee60>,
#  <__main__.Order at 0x7e3b6e91ed70>,
#  <__main__.Order at 0x7e3b6e91ee00>,
#  <__main__.Order at 0x7e3b6e91f370>,
#  <__main__.Order at 0x7e3b6e91edd0>,
#  <__main__.Order at 0x7e3b6e91e1a0>,
#  <__main__.Order at 0x7e3b6e91e1d0>,
#  <__main__.Order at 0x7e3b6e91e0b0>,
#  <__main__.Order at 0x7e3b6e91d3c0>,
#  <__main__.Order at 0x7e3b6e91e5f0>,
#  <__main__.Order at 0x7e3b6e91e6e0>,
#  <__main__.Order at 0x7e3b6e91f5b0>,
#  <__main__.Order at 0x7e3b6e91eda0>,
#  <__main__.Order at 0x7e3b6e91ee90>,
#  <__main__.Order at 0x7e3b6e91efb0>,
#  <__main__.Order at 0x7e3b6e91ee30>,
#  <__main__.Order at 0x7e3b6ea02f50>,
#  <__main__.Order at 0x7e3b6ea039d0>,
#  <__main__.Order at 0x7e3b6ea02fe0>,
#  <__main__.Order at 0x7e3b6ea02f20>,
#  <__main__.Order at 0x7e3b6ea02ef0>,
#  <__main__.Order at 0x7e3b6ea02e00>,
#  <__main__.Order at 0x7e3b6ea03040>,
#  <__main__.Order at 0x7e3b6ea03640>,
#  <__main__.Order at 0x7e3b6ea039a0>,
#  <__main__.Order at 0x7e3b6ea0caf0>,
#  <__main__.Order at 0x7e3b6ea02fb0>,
#  <__main__.Order at 0x7e3b6ea03a30>,
#  <__main__.Order at 0x7e3b6ea0e2c0>,
#  <__main__.Order at 0x7e3b6ea02e90>,
#  <__main__.Order at 0x7e3b6ea0d060>,
#  <__main__.Order at 0x7e3b6ea0e140>,
#  <__main__.Order at 0x7e3b6ea0dde0>,
#  <__main__.Order at 0x7e3b6ea0cc10>,
#  <__main__.Order at 0x7e3b6ea0cc70>,
#  <__main__.Order at 0x7e3b6ea0d150>,
#  <__main__.Order at 0x7e3b6ea0dba0>,
#  <__main__.Order at 0x7e3b6e903880>,
#  <__main__.Order at 0x7e3b6e902dd0>,
#  <__main__.Order at 0x7e3b6e903790>,
#  <__main__.Order at 0x7e3b6e903610>,
#  <__main__.Order at 0x7e3b6e9039a0>,
#  <__main__.Order at 0x7e3b6e9001f0>,
#  <__main__.Order at 0x7e3b6e903f70>,
#  <__main__.Order at 0x7e3b6e903550>,
#  <__main__.Order at 0x7e3b6e9035e0>,
#  <__main__.Order at 0x7e3b6e903310>,
#  <__main__.Order at 0x7e3b6e9035b0>,
#  <__main__.Order at 0x7e3b6e903850>,
#  <__main__.Order at 0x7e3b6e91f6a0>,
#  <__main__.Order at 0x7e3b6e91ed40>,
#  <__main__.Order at 0x7e3b6e91de10>,
#  <__main__.Order at 0x7e3b6e91f910>,
#  <__main__.Order at 0x7e3b6e91f640>,
#  <__main__.Order at 0x7e3b6e91e140>,
#  <__main__.Order at 0x7e3b6e91e500>,
#  <__main__.Order at 0x7e3b6e91d270>,
#  <__main__.Order at 0x7e3b6e91d180>,
#  <__main__.Order at 0x7e3b6e91d570>,
#  <__main__.Order at 0x7e3b6e91d090>,
#  <__main__.Order at 0x7e3b6e91cfd0>,
#  <__main__.Order at 0x7e3b6e91d000>,
#  <__main__.Order at 0x7e3b6e91da20>,
#  <__main__.Order at 0x7e3b6e91ece0>,
#  <__main__.Order at 0x7e3b6e91e9b0>,
#  <__main__.Order at 0x7e3b6e91f2e0>,
#  <__main__.Order at 0x7e3b6e91d450>,
#  <__main__.Order at 0x7e3b6e91e2c0>,
#  <__main__.Order at 0x7e3b6e91f130>,
#  <__main__.Order at 0x7e3b6e91e4a0>,
#  <__main__.Order at 0x7e3b6e91d870>,
#  <__main__.Order at 0x7e3b6e91dc30>,
#  <__main__.Order at 0x7e3b6e91ebc0>,
#  <__main__.Order at 0x7e3b6e91e800>,
#  <__main__.Order at 0x7e3b6cbf34f0>,
#  <__main__.Order at 0x7e3b6cbf3490>,
#  <__main__.Order at 0x7e3b6cbf1a80>,
#  <__main__.Order at 0x7e3b6cbf3e20>]

# %% [markdown]
# ## **Export to CSV**

# %%
exchange_report = pd.DataFrame(invalid_orders)
exchange_report.to_csv('/content/drive/MyDrive/BoA 2024/output_exchange_report.csv', index=False)

# %%
client_report = pd.DataFrame(client_position)
client_report.to_csv('/content/drive/MyDrive/BoA 2024/output_client_report.csv', index=False)
